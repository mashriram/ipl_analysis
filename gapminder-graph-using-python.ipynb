# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %% [markdown]
# **This Notebook made as a first try and exploration of the pandas and seaborn visualiazation features.**

# %%
gapminder_filepath = "input/gapminder - gapminder.csv"
gapminder_data = pd.read_csv(gapminder_filepath, index_col='country')
gapminder_data.head()
# Out:
#              Unnamed: 0  year  population continent  life_exp       gdp_cap
# country
# Afghanistan          11  2007    31889923      Asia    43.828    974.580338
# Albania              23  2007     3600523    Europe    76.423   5937.029526
# Algeria              35  2007    33333216    Africa    72.301   6223.367465
# Angola               47  2007    12420476    Africa    42.731   4797.231267
# Argentina            59  2007    40301927  Americas    75.320  12779.379640

# %% [markdown]
# Let's make a simple line plot from our data.

# %%
plt.plot(gapminder_data.gdp_cap, gapminder_data.life_exp)
plt.show()

# %% [markdown]
# But this doesn't look right. 😂
#
# For this type of comparison - let's make a simple scatter plot.

# %%
plt.scatter(gapminder_data.gdp_cap, gapminder_data.life_exp)
#A correlation will become clear, when you display the GDP per capita on a logarithmic scale
plt.xscale('log')
plt.show()

# %% [markdown]
# **Can we draw any conclutions?**
#
# The higher GDP usually corresponds to a higher life expectancy. In other words, there is a positive correlation.

# %% [markdown]
# Let's create a histogram of life expectancy.

# %%
plt.hist(gapminder_data.life_exp)
plt.show()

# %%
#with more bins for clear visibility
plt.hist(gapminder_data.life_exp, bins=20)
plt.show()

# %% [markdown]
# 4. Let's get back to our scatter plot and improve it.

# %%
plt.scatter(gapminder_data.gdp_cap, gapminder_data.life_exp)
plt.xscale('log')
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.show()

# %% [markdown]
# Let's replace the tick values 1000, 10000 and 100000 with 1k, 10k and 100k.

# %%
plt.scatter(gapminder_data.gdp_cap, gapminder_data.life_exp)
plt.xscale('log')
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
plt.show()

# %% [markdown]
# Wouldn't it be nice if the size of the dots corresponds to the population?

# %%
# Store population as a numpy array: np_pop
np_pop = np.array(gapminder_data.population)
np_pop2 = np_pop*2
#Use seaborn scatterplot for better customization
sns.scatterplot(x=gapminder_data['gdp_cap'], y=gapminder_data['life_exp'], hue = gapminder_data['continent'], size = np_pop2, sizes=(20,400))
plt.grid(True)
plt.xscale('log')
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
plt.show()

# %% [markdown]
# Let's increase the size of the graph and fonts of the labels. Remove the legend.

# %%
# Increase the graph size
plt.figure(dpi=220)
# Store population as a numpy array: np_pop
np_pop = np.array(gapminder_data.population)
np_pop2 = np_pop*2
#Let's delete the annoying legend
sns.scatterplot(x=gapminder_data['gdp_cap'], y=gapminder_data['life_exp'], hue = gapminder_data['continent'], size=np_pop2, sizes=(20,400), legend = False)
plt.grid(True)
plt.xscale('log')
plt.xlabel('GDP per Capita [in USD]', fontsize = 12)
plt.ylabel('Life Expectancy [in years]', fontsize = 12)
plt.title('World Development in 2007', fontsize = 16)
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
plt.show()

# %% [markdown]
# Let's add some description to the biggest countries.

# %%
# Increase the graph size
plt.figure(dpi=150)
# Store population as a numpy array: np_pop
np_pop = np.array(gapminder_data.population)
np_pop2 = np_pop*2
#Let's change the opacity 
sns.scatterplot(x=gapminder_data['gdp_cap'], y=gapminder_data['life_exp'], hue = gapminder_data['continent'], legend = False, 
                size=np_pop2, sizes=(20,500), alpha = 0.8)
plt.grid(True)
plt.xscale('log')
plt.xlabel('GDP per Capita [in USD]', fontsize = 14)
plt.ylabel('Life Expectancy [in years]', fontsize = 14)
plt.title('World Development in 2007', fontsize = 20)
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
#Add description to the biggest countries
plt.text(1550, 67, 'India')
plt.text(5650, 75, 'China')
plt.show()

# %% [markdown]
# This is looking more and more like Hans Rosling's plot! 🥳
